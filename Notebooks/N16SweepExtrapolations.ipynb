# %% [markdown]
# ### 3-parameter exponential fitted $\beta$-scaling

# %% [markdown]
# Want to fit observable data as a function of $\beta$ to the form:
# $$
# \mathcal{O}(\beta) = \mathcal{O}_{\beta\to\infty} + C_1 e^{-C_2 \beta}
# $$

# %% [markdown]
# where $\mathcal{O}_{\beta\to\infty}$,$C_1$, and $C_2$ are fitting parameters. The $\mathcal{O}_{\beta\to\infty}$ parameter will give a large $\beta$ extrapolation of the observable in question. Here, we will focus on the second Rényi entanglement entropy $S_2$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy 
from scipy import optimize

# %% [markdown]
# Define the exponential model

# %%
def exponential(x, c1, c2, c3):
    return c3 + c1*np.exp(-x*c2)

# %%
# Array where extrapolated S2s will be saved to
extrapolated_S2s = np.zeros(15)
extrapolated_S2s_err = np.zeros(15)

# %% [markdown]
# Feed data points (obtained from a separate script)

# %%
# Define data points
x_array = np.array([2,4,6,8,10,12]) # betas

# %%
# Obtained with entanglement_combiner.py for betas
U = 0.500000
y_array_exp = np.array([1.80386182090286, 1.680359013159121, 1.6422591339100119, 1.6166652908188335, 1.6208867763512447, 1.617508246750636])
sigmas = np.array([0.003366406210058754, 0.004013663634867427, 0.004884575659882536, 0.005464494198633294, 0.005528597269113905, 0.005953459016439087])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[0] = c3
extrapolated_S2s_err[0] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.615615 +/- 0.003527

# %%
# Obtained with entanglement_combiner.py for betas
U = 0.730000
y_array_exp = np.array([1.719315387772839, 1.6072425934616483, 1.5752050634215162, 1.5729683778873396, 1.5703773537884111, 1.5704499215485357])
sigmas = np.array([0.0031624313986608793, 0.004121898099371819, 0.004640075913716278, 0.005315497018236406, 0.005136601872866878, 0.005561349403301756])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[1] = c3
extrapolated_S2s_err[1] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.569408 +/- 0.001467

# %%
# Obtained with entanglement_combiner.py for betas
U = 1.0658
y_array_exp = np.array([1.6292280399384826, 1.5343738684253347, 1.5097303665154662, 1.5048923819878186, 1.5054013891118503, 1.519485564474345])
sigmas = np.array([0.0030001773481151527, 0.0033173972112158943, 0.004661854277426273, 0.00459098801749793, 0.00524152446026826, 0.006239147661135381])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[2] = c3
extrapolated_S2s_err[2] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.507231 +/- 0.003939

# %%
# Obtained with entanglement_combiner.py for betas
U = 1.5561
y_array_exp = np.array([1.5357999418778707, 1.4540791234404185, 1.4388344010265357, 1.4425924486601531, 1.4471744875452006, 1.433806302891976])
sigmas = np.array([0.003173795215773503, 0.0037063079839219967, 0.004056356423715645, 0.004724432600176516, 0.005368816316796016, 0.005565507847217192])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[3] = c3
extrapolated_S2s_err[3] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.440047 +/- 0.003065

# %%
# Obtained with entanglement_combiner.py for betas
U = 2.272
y_array_exp = np.array([1.4309130581124023, 1.3699861850397954, 1.3526958210936852, 1.3503146349343975, 1.3464105786698375, 1.3544747513094757])
sigmas = np.array([0.002874296314811428, 0.003531593566375085, 0.0033026876540371117, 0.0052803303585076105, 0.005274670428732357, 0.005443692851034297])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[4] = c3
extrapolated_S2s_err[4] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.349139 +/- 0.002121

# %%
# Obtained with entanglement_combiner.py for betas
U = 3.3
y_array_exp = np.array([1.3016891994663609, 1.2417752603662948, 1.2247974540973467, 1.2300436875495162, 1.227867150049772, 1.2360658597747933])
sigmas = np.array([0.002527528861245571, 0.003074487255073985, 0.0038815579102343956, 0.00442529498487249, 0.004745071094412086, 0.0050262318393041044])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[5] = c3
extrapolated_S2s_err[5] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.228873 +/- 0.003146

# %%
# Obtained with entanglement_combiner.py for betas
U = 4.843100
y_array_exp = np.array([1.0846380957910753, 0.9328617802996798, 0.8900977491891365, 0.8783212375568124, 0.8775482196837211, 0.8762836151084634])
sigmas = np.array([0.0011994089478955703, 0.0016684557251888364, 0.0018023438858168997, 0.001885658146357462, 0.002365930266615556, 0.0021495803480572947])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[6] = c3
extrapolated_S2s_err[6] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.875168 +/- 0.000750

# %%
# Obtained with entanglement_combiner.py for betas
U = 7.0711
y_array_exp = np.array([0.5341375283432073, 0.37419236901416886, 0.3682988704759189, 0.36786952667711426, 0.36675474487008347, 0.36531063289421317])
sigmas = np.array([0.0009651834237534852, 0.001445439276728836, 0.0018279706672452451, 0.0017506911924556167, 0.002112598640621439, 0.0021145288487066285])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[7] = c3
extrapolated_S2s_err[7] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.367113 +/- 0.000618

# %%
# Define data points
x_array = np.array([1,2,4,6,8,10,12]) # betas

# %%
# Obtained with entanglement_combiner.py for betas
U = 10.3239
y_array_exp = np.array([0.3846989920420492, 0.165343136040867, 0.15933726970419657, 0.15921125140816642, 0.15980209589609223, 0.16093592719027525, 0.15711277892899195])
sigmas = np.array([0.00024716889788792577, 0.0002735048274175943, 0.00038156114456241037, 0.00040794243257747417, 0.00044693547658746885, 0.0005228782469472051, 0.0005948262703914566])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[8] = c3
extrapolated_S2s_err[8] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.159382 +/- 0.000501

# %%
# Obtained with entanglement_combiner.py for betas
U = 16.666667
y_array_exp = np.array([0.06178639906938851, 0.058854691568405094, 0.059094021100469775, 0.059264784639989146, 0.05913418160869979, 0.05895803148713737, 0.05867162367835831])
sigmas = np.array([0.00027397901120447755, 0.00028714165645908146, 0.0004353116490651759, 0.0002967672299124708, 0.0003058366356456915, 0.00032625322852125333, 0.00028777416506142853])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[9] = c3
extrapolated_S2s_err[9] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.059074 +/- 0.000108

# %%
# Obtained with entanglement_combiner.py for betas
U = 22.0071
y_array_exp = np.array([0.03388600395180476, 0.03369587310946034, 0.03382660724229952, 0.03358266771231893, 0.030295102326956327, 0.033773607328640286, 0.033520148607300966])
sigmas = np.array([0.00021342686475730785, 0.00014527617455893627, 0.00021050415592738697, 0.00021362148103799732, 0.003087826348072021, 0.0001852139142117248, 0.00020155409685866836])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[10] = c3
extrapolated_S2s_err[10] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.033675 +/- 0.000085

# %%
# Obtained with entanglement_combiner.py for betas
U = 32.1308
y_array_exp = np.array([0.015868980810010567, 0.016259471343882594, 0.014550485216635552, 0.01565577461384018, 0.015916011994758995, 0.016601719511046716, 0.01596082479028629])
sigmas = np.array([0.0001329643812352805, 0.0005583817232901597, 0.0006495868031802457, 0.0006470465842743413, 0.0006528218367851061, 0.000566497949100759, 0.0005610052295243051])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[11] = c3
extrapolated_S2s_err[11] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.015887 +/- 0.000346

# %%
# Obtained with entanglement_combiner.py for betas
U = 46.9117
y_array_exp = np.array([0.007828316199440839, 0.0075376625510448795, 0.007453467425056638, 0.007341086371023734, 0.007214798966375404, 0.007143441122991042, 0.007300496479640682])
sigmas = np.array([0.00011438832739124523, 0.00013423187008625522, 0.0001914154161000281, 0.00016184709667172793, 0.00015343514195650205, 0.0001786824194991343, 0.00016008612113819812])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[12] = c3
extrapolated_S2s_err[12] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.007237 +/- 0.000054

# %%
# Obtained with entanglement_combiner.py for betas
U = 68.4921
y_array_exp = np.array([0.0039435356990426265, 0.0034342360005547696, 0.003776037913271347, -0.003874146057115102, 0.0029188372705925645, 0.0038460398038209966, 0.0034525607296182976])
sigmas = np.array([0.00010055885898827987, 0.00034640658452969906, 0.0004899518052439625, 0.007220026275181353, 0.00037631424173042635, 0.00034881704147324966, 0.0003713567787156626])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[13] = c3
extrapolated_S2s_err[13] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.003423 +/- 0.000472

# %%
# Obtained with entanglement_combiner.py for betas
U = 100.0
y_array_exp = np.array([0.0020704506828257917, 0.001869917070431495, 0.0014949687434322432, 0.0017903901546211592, 0.0018869707092077975, 0.0016705889205872325, 0.0017374855626387355])
sigmas = np.array([8.896615214580727e-05, 9.790392184359382e-05, 0.00013672084741799532, 0.000125236335349207, 0.00011740883025975195, 0.00011234374106654182, 0.00011160062621187341])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[14] = c3
extrapolated_S2s_err[14] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.001732 +/- 0.000066

# %% [markdown]
# Perform exponential fit to data with Scipy curve_fit

# %%
print(list(extrapolated_S2s))
print(list(extrapolated_S2s_err))
# Out:
# [1.6156150234068303, 1.5694076086589193, 1.5072311926100799, 1.4400472089238747, 1.3491392555625747, 1.2288726341586773, 0.8751683790987755, 0.3671126283924669, 0.15938249324937237, 0.05907417214946625, 0.03367479180340462, 0.01588728101438945, 0.007236771641036834, 0.0034226537158845802, 0.001732112962342956]
# [0.003527381510594486, 0.0014673986390165332, 0.003939062702089423, 0.0030652050488908554, 0.0021206567728591454, 0.003146249738696877, 0.0007502829663701376, 0.0006181048179824724, 0.0005012451667065351, 0.00010848581581552149, 8.469792958202551e-05, 0.000346025677136763, 5.3899483681983876e-05, 0.0004722869940240065, 6.616196943435604e-05]

# %%
# Save the extrapolations to file here
