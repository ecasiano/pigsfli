# %% [markdown]
# ### 3-parameter exponential fitted $\beta$-scaling

# %% [markdown]
# Want to fit observable data as a function of $\beta$ to the form:
# $$
# \mathcal{O}(\beta) = \mathcal{O}_{\beta\to\infty} + C_1 e^{-C_2 \beta}
# $$

# %% [markdown]
# where $\mathcal{O}_{\beta\to\infty}$,$C_1$, and $C_2$ are fitting parameters. The $\mathcal{O}_{\beta\to\infty}$ parameter will give a large $\beta$ extrapolation of the observable in question. Here, we will focus on the second Rényi entanglement entropy $S_2$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy 
from scipy import optimize

# %% [markdown]
# Define the exponential model

# %%
def exponential(x, c1, c2, c3):
    return c3 + c1*np.exp(-x*c2)

# %%
# Array where extrapolated S2s will be saved to
extrapolated_S2s = np.zeros(15)
extrapolated_S2s_err = np.zeros(15)

# %% [markdown]
# Feed data points (obtained from a separate script)

# %%
# Define data points
x_array = np.array([1,2,4,8,16,32]) # betas

# %%
# Obtained with entanglement_combiner.py for betas
U = 0.500000
y_array_exp = np.array([3.334216786398752, 3.1440569987773106, 2.9699980319335504, 2.749671415148893, 2.597631539895206, 2.5055685645591614])
sigmas = np.array([0.008516264864420121, 0.009506072584903229, 0.007589700600520476, 0.008400438781062964, 0.01100441603672853, 0.021672713279809578])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[2:], y_array_exp[2:],sigma=sigmas[2:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[0] = c3
extrapolated_S2s_err[0] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 2.523991 +/- 0.029386

# %%
# Obtained with entanglement_combiner.py for betas
U = 0.730000
y_array_exp = np.array([3.2298477499618112, 3.0528064901619, 2.8391342491575986, 2.655563430501945, 2.473230890916429, 2.385120870935642])
sigmas = np.array([0.0073468677494322645, 0.008611250251664856, 0.008334843359031568, 0.008576329984207107, 0.010494385734928495, 0.019740460019670874])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[2:], y_array_exp[2:],sigma=sigmas[2:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[1] = c3
extrapolated_S2s_err[1] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 2.368975 +/- 0.003893

# %%
# Obtained with entanglement_combiner.py for betas
U = 1.0658
y_array_exp = np.array([3.1312647223119683, 2.9385880120818144, 2.722573335749136, 2.534636387649761, 2.390786053734234, 2.3010791585290047])
sigmas = np.array([0.007811418613253126, 0.009159914261365915, 0.006737627221784018, 0.00908847256741282, 0.009845982551081623, 0.019446785375176558])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[2:], y_array_exp[2:],sigma=sigmas[2:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[2] = c3
extrapolated_S2s_err[2] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 2.309074 +/- 0.025758

# %%
# Obtained with entanglement_combiner.py for betas
U = 1.5561
y_array_exp = np.array([3.0295034372358134, 2.813009805128862, 2.589982582459615, 2.406181480307823, 2.2872323126056093, 2.184508521427287])
sigmas = np.array([0.0068550889429548475, 0.00805540534064155, 0.007490535229112242, 0.007324022599890754, 0.009546973970318248, 0.01547347182948131])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[2:], y_array_exp[2:],sigma=sigmas[2:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[3] = c3
extrapolated_S2s_err[3] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 2.201914 +/- 0.044246

# %%
# Obtained with entanglement_combiner.py for betas
U = 2.272
y_array_exp = np.array([2.899682293845545, 2.6726950196907895, 2.46340087947448, 2.2786167400914543, 2.154463963353433, 2.080399547717518])
sigmas = np.array([0.007302703167155858, 0.008646982682276476, 0.008940381956679604, 0.010831293166793965, 0.009996782039308637, 0.02022025082463989])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[2:], y_array_exp[2:],sigma=sigmas[2:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[4] = c3
extrapolated_S2s_err[4] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 2.094977 +/- 0.013430

# %%
# Obtained with entanglement_combiner.py for betas
U = 3.3
y_array_exp = np.array([2.7613983509846114, 2.5278798754190115, 2.3215927074027314, 2.1393276063288917, 2.012541234818751, 1.925486132845557])
sigmas = np.array([0.006387212146729307, 0.007299963517063232, 0.009234212763322217, 0.010950855787696456, 0.012807460362741163, 0.016829448228782164])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[2:], y_array_exp[2:],sigma=sigmas[2:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[5] = c3
extrapolated_S2s_err[5] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.930074 +/- 0.027573

# %%
# Obtained with entanglement_combiner.py for betas
U = 4.843100
y_array_exp = np.array([2.5949650686015766, 2.33849281137475, 2.081700465390683, 1.8033595284561776, 1.1812361157715137, 0.9066251371182852])
sigmas = np.array([0.004281465265263768, 0.004876621878029813, 0.005097765208600728, 0.006425931575223132, 0.013671553413699437, 0.028397139423546942])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[6] = c3
extrapolated_S2s_err[6] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.888488 +/- 0.369753

# %%
# Obtained with entanglement_combiner.py for betas
U = 7.0711
y_array_exp = np.array([2.36881910206299, 1.9353913060106287, 0.8993890800046613, 0.4194208372729237, 0.3616233368773248, 0.35237729225719333])
sigmas = np.array([0.007679047194023742, 0.007586381606805852, 0.01479364598223315, 0.046385319868244415, 0.02692182188651475, 0.029585789968612462])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[7] = c3
extrapolated_S2s_err[7] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.356737 +/- 0.002854

# %%
# Obtained with entanglement_combiner.py for betas
U = 10.3239
y_array_exp = np.array([1.9234328200625297, 0.5129459931055496, 0.1776729919798142, 0.14957124850079034, 0.18315754809848733, 0.16488178815365492])
sigmas = np.array([0.004852774880230008, 0.009358050957287823, 0.02679475842314161, 0.01901585715791214, 0.017797969318923995, 0.02000603502803476])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[8] = c3
extrapolated_S2s_err[8] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.166376 +/- 0.007670

# %%
# Obtained with entanglement_combiner.py for betas
U = 16.666667
y_array_exp = np.array([0.32793043173873626, 0.057215942230717215, 0.05472821750311609, 0.05115587434808927, 0.04861535649838345, 0.04175627254279044])
sigmas = np.array([0.005288545421160783, 0.010325436216640104, 0.00843608200045646, 0.00830055761128991, 0.00977921337082141, 0.010595819044005307])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[9] = c3
extrapolated_S2s_err[9] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.049898 +/- 0.002582

# %%
# Obtained with entanglement_combiner.py for betas
U = 22.0071
y_array_exp = np.array([0.02838186457474578, 0.030885319449809604, 0.03368827379772576, 0.044069908700291455, 0.039948868211033904, 0.03743427158571932])
sigmas = np.array([0.007328366494200307, 0.005857366246245793, 0.006298854279501101, 0.006803504497838571, 0.007246409899670958, 0.008191973446396602])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[10] = c3
extrapolated_S2s_err[10] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.040532 +/- 0.002646

# %%
# Obtained with entanglement_combiner.py for betas
U = 32.1308
y_array_exp = np.array([0.013194541642879677, 0.016687045443824308, 0.01727742003261506, 0.021588348813621365, 0.014026477366399831, 0.012810083845934156])
sigmas = np.array([0.0044921745026242675, 0.004546829740470817, 0.004452294864995721, 0.004716371287249666, 0.005409172288299409, 0.00637219075296589])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[11] = c3
extrapolated_S2s_err[11] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.017100 +/- 0.001927

# %%
# Obtained with entanglement_combiner.py for betas
U = 46.9117
y_array_exp = np.array([0.011975254461597478, 0.00714634986350749, 0.00631973720095834, 0.012572420586812296, 0.007214803971177706, 0.004352946361474863])
sigmas = np.array([0.001981687579267321, 0.0021698366762145363, 0.0020629380224017157, 0.00238304213060439, 0.002843742762336473, 0.003792688567386558])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[12] = c3
extrapolated_S2s_err[12] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.008594 +/- 0.003195

# %%
# Obtained with entanglement_combiner.py for betas
U = 68.4921
y_array_exp = np.array([0.0041598078361510865, 0.005697165138979387, 0.003891335317835564, 0.003445170475019677, 0.003982451686186989, 0.003447134091594893])
sigmas = np.array([0.001576181525112772, 0.0017596589679705213, 0.0018481363705171836, 0.0017095024365138029, 0.0020388623874246356, 0.002364786974465777])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[13] = c3
extrapolated_S2s_err[13] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.003617 +/- 0.000181

# %%
# Obtained with entanglement_combiner.py for betas
U = 100.0
y_array_exp = np.array([0.0008842567962603439, 0.0029379114616680814, 0.0036101085812428268, -0.0007594559946462894, 0.0022048803234965496, 0.0016411989546814146])
sigmas = np.array([0.0016393254164873289, 0.0025004480850612226, 0.0016812014521716977, 0.001871812828355539, 0.0020268740309185834, 0.0023702678793243253])

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, x_array[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[14] = c3
extrapolated_S2s_err[14] = c3_err

# Perform the fit
betas_fit = np.linspace(min(x_array),max(x_array)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(x_array,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.001145 +/- 0.001627

# %% [markdown]
# Perform exponential fit to data with Scipy curve_fit

# %%
print(list(extrapolated_S2s))
print(list(extrapolated_S2s_err))
# Out:
# [2.5239912695238833, 2.368975442192509, 2.3090741214420825, 2.2019141108981692, 2.0949771228071383, 1.9300737357448878, 0.8884881377552545, 0.3567373904081745, 0.16637587650780666, 0.04989772299081139, 0.04053236606704449, 0.01709983362102333, 0.008594450746295904, 0.0036169306970674003, 0.0011448982636767387]
# [0.02938587934834009, 0.003893065606697477, 0.025757753542229228, 0.04424636186799337, 0.01342956074857467, 0.02757335387200755, 0.36975346836835743, 0.0028536334412077274, 0.007670275864618744, 0.0025824048263460436, 0.0026457513229081434, 0.001926782747414821, 0.003194842975139299, 0.00018105680733479152, 0.0016265373281066243]

# %%
# Save the extrapolations to file here
