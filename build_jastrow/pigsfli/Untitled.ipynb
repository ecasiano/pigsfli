# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('output.dat')

# %%
data_stride = data[::10,:]

# %%
moves = data_stride[:,-1]
idx0 = np.where(moves==0)

# %%
data0 = data_stride[idx0,:]

# %%
data0.shape
# Out:
# (1, 1476, 5)

# %%
data0[0,:10,3]
# Out:
# array([409.55 , 410.673, 346.046, 346.754, 347.721, 347.721, 341.612,
#        408.852, 419.334, 410.974])

# %%
plt.plot(data0[0,:,3])
